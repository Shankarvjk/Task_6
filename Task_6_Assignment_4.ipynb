# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('Data/Boston Housing Dataset/data/train.csv')
train
# Out:
#       ID     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0      0  0.95577   0.0   8.14     0  0.538  6.047   88.8  4.4534    4  307.0
# 1      1  0.02875  28.0  15.04     0  0.464  6.211   28.9  3.6659    4  270.0
# 2      2  1.22358   0.0  19.58     0  0.605  6.943   97.4  1.8773    5  403.0
# 3      3  5.66637   0.0  18.10     0  0.740  6.219  100.0  2.0048   24  666.0
# 4      4  0.04544   0.0   3.24     0  0.460  6.144   32.2  5.8736    4  430.0
# ..   ...      ...   ...    ...   ...    ...    ...    ...     ...  ...    ...
# 395  395  0.03615  80.0   4.95     0  0.411  6.630   23.4  5.1167    4  245.0
# 396  396  0.17505   0.0   5.96     0  0.499  5.966   30.2  3.8473    5  279.0
# 397  397  6.65492   0.0  18.10     0  0.713  6.317   83.0  2.7344   24  666.0
# 398  398  0.13117   0.0   8.56     0  0.520  6.127   85.2  2.1224    5  384.0
# 399  399  0.06466  70.0   2.24     0  0.400  6.345   20.1  7.8278    5  358.0
#
# ...

# %%
test = pd.read_csv('Data/Boston Housing Dataset/data/test.csv')
test
# Out:
#       ID      CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0      0   0.10612  30.0   4.93     0  0.428  6.095  65.1  6.3361    6  300.0
# 1      1   0.34109   0.0   7.38     0  0.493  6.415  40.1  4.7211    5  287.0
# 2      2  12.24720   0.0  18.10     0  0.584  5.837  59.7  1.9976   24  666.0
# 3      3   0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311.0
# 4      4   1.80028   0.0  19.58     0  0.605  5.877  79.2  2.4259    5  403.0
# ..   ...       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 100  100   0.19073  22.0   5.86     0  0.431  6.718  17.5  7.8265    7  330.0
# 101  101   6.96215   0.0  18.10     0  0.700  5.713  97.0  1.9265   24  666.0
# 102  102   0.05360  21.0   5.64     0  0.439  6.511  21.1  6.8147    4  243.0
# 103  103   0.10469  40.0   6.41     1  0.447  7.267  49.0  4.7872    4  254.0
# 104  104   4.55587   0.0  18.10     0  0.718  3.561  87.9  1.6132   24  666.0
#
#      PTRATIO       B  LSTAT
# ...

# %%
# Import phi and phi_test from train and test datasets using NumPy's loadtxt function

phi = np.loadtxt('Data/Boston Housing Dataset/data/train.csv', dtype='float', delimiter=',', skiprows=1, usecols=tuple(range(1, 14)))
phi_test = np.loadtxt('Data/Boston Housing Dataset/data/test.csv', dtype='float', delimiter=',', skiprows=1, usecols=tuple(range(1, 14)))

# %%
# Import y from train dataset using the loadtxt function

y = np.loadtxt('Data/Boston Housing Dataset/data/train.csv', dtype='float', delimiter=',', skiprows=1, usecols=14, ndmin=2)

# %%
# Concatenate coloumn of 1s to right of phi and phi_test

phi = np.concatenate((phi, np.ones((400,1))), axis=1)
phi_test = np.concatenate((phi_test, np.ones((105,1))), axis=1)

# %%
# Apply min max scaling on each coloumn of phi and phi_test

for i in range(0, 13):
    col_max = max(phi[:, i])
    col_min = min(phi[:, i])
    phi[:, i] = (phi[:, i] - col_min) / (col_max - col_min)
    phi_test[:, i] = (phi_test[:, i] - col_min) / (col_max - col_min)

# %%
# Log scaling on y

y = np.log(y)

# %%
# Function to calculate change in error function

def delta_w(p, phi, w):
    if p == 2:
        deltaw = (2 * (np.dot(np.dot(np.transpose(phi), phi), w) -
                       np.dot(np.transpose(phi), y)) +
                  lambd * p * np.power(np.absolute(w), (p - 1)))
    if p < 2 and p > 1:
        deltaw = (2 * (np.dot(np.dot(np.transpose(phi), phi), w) -
                       np.dot(np.transpose(phi), y)) +
                  lambd * p * np.power(np.absolute(w), (p - 1)) * np.sign(w))
    return deltaw

# %%
# Dictionary containing filenames as keys and p as values

filenames = {'Data/Boston Housing Dataset/data/output.csv': 2.0,
             'Data/Boston Housing Dataset/data/output_p1.csv': 1.75,
             'Data/Boston Housing Dataset/data/output_p2.csv': 1.5,
             'Data/Boston Housing Dataset/data/output_p3.csv': 1.3}

# %%
# For each item in this dictionary
for (fname, p) in filenames.items():
    # Set initial w to zeros
    w = np.zeros((14, 1))

    # Hyperparameter lambda value
    lambd = 0.2

    # Maximum step size
    t = 0.00012

    # Calculate new value of w
    w_new = w - t * delta_w(p, phi, w)

    i = 0
    # Repeat steps until error between consecutive w is less than threshold
    while(np.linalg.norm(w_new-w) > 10 ** -10):
        w = w_new
        w_new = w - t * delta_w(p, phi, w)
        i = i + 1

    # Load values of id
    id_test = np.loadtxt('Data/Boston Housing Dataset/data/test.csv', dtype='int', delimiter=',', skiprows=1, usecols=0, ndmin=2)

    # Calculate y for test data
    y_test = np.exp(np.dot(phi_test, w_new))

    # Save the ids and y
    np.savetxt(fname, np.concatenate((id_test, y_test), axis=1), delimiter=',', fmt=['%d', '%f'], header='ID,MEDV', comments='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#      10 t = 0.00012
#      12 # Calculate new value of w
# ---> 13 w_new = w - t * delta_w(p, phi, w)
#      15 i = 0
#      16 # Repeat steps until error between consecutive w is less than threshold
#
# Input In [19], in delta_w(p, phi, w)
#       1 def delta_w(p, phi, w):
#       2     if p == 2:
# ----> 3         deltaw = (2 * (np.dot(np.dot(np.transpose(phi), phi), w) -
#       4                        np.dot(np.transpose(phi), y)) +
#       5                   lambd * p * np.power(np.absolute(w), (p - 1)))
#       6     if p < 2 and p > 1:
#       7         deltaw = (2 * (np.dot(np.dot(np.transpose(phi), phi), w) -
#       8                        np.dot(np.transpose(phi), y)) +
#       9                   lambd * p * np.power(np.absolute(w), (p - 1)) * np.sign(w))
#
# ...
